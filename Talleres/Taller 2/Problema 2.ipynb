# %%
# Problema 2
#Esta es la función de seis jorobas de camello donde tanto  𝑥  como  𝑦  se encuentran entre  ±5 . El objetivo es minimizar  𝑧 . El mínimo global se encuentra en (-0.089840, 0.712659) o (0.089840, -0.712659) donde  𝑧=−1.0316285 .

#𝑧=(4−2.1𝑥2+𝑥43)𝑥2+𝑥𝑦+(−4+4𝑦2)𝑦2

# %%
from deap import algorithms, base, creator, tools
import random
import numpy as np

# %%
creator.create("FitnessMin", base.Fitness, weights=(-1.0,)) # -1 -> minimum problem
creator.create("Individual", list, fitness=creator.FitnessMin)

# %%
toolbox = base.Toolbox()

# %%
def obtIndividuo(): # Funcion para generar un atributo del individuo can valores entre -5 y 5
    x= random.uniform(-5,5)
    return x

# %%
indv = obtIndividuo()
indv
# Out:
# -2.370602065389483

# %%
# registro del generador de atributos
toolbox.register("attr_bool", obtIndividuo)

# %%
#prueba de generador de atributos
c=toolbox.attr_bool()
print(c)
# Out:
# 1.5248266843109484

# %%
# Inicializador de estructuras
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, 2)
#Se establece que el induviduo se genera con 2 atributos
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
#prueba de generador de poblacion
d=toolbox.population(n=5)
print(d)
# Out:
# [[4.281472295243642, -2.72193912400272], [-3.250151938400597, -4.893115770468968], [4.789829270723343, 4.480906797828064], [-4.672296677632217, 0.18165030530206572], [-1.1248503911823473, -0.34196899274350656]]

# %%
#Función de evaluación
#Retorna el valor de z, segun la ecuacion dada en el ejercicio

def eval(individual):
    i1= individual[0] 
    i2= individual[1] 
    x1=2.1*(i1**2)
    x2=4-x1
    x3=x2+((i1**4)/3)
    x4=x3*(i1**2)
    x5=i1*i2
    x6=(-4+(4*(i2**2)))
    x7=x6*(i2**2)
    z=x4+x5+x7
    return z,

# %%
# registro de la funcion de evaluacion
toolbox.register("evaluate", eval)

# %%
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutUniformInt, low=-5.00, up=5.00, indpb=0.3)
toolbox.register("select", tools.selTournament, tournsize=3)

# %%
#creacion de poblacion
pop = toolbox.population(n=300)
#pop

# %%
#Uso de un HallOfFame para hacer un seguimiento del mejor individuo que aparece en la evolución
hof = tools.HallOfFame(1)

# %%
# Estadisticas
stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", np.mean)
stats.register("std", np.std)
stats.register("min", np.min)
stats.register("max", np.max)

# %%
# algorithms : contiene implementaciones utiles de algunos AG basicos
pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.3, ngen=200, stats=stats, halloffame=hof, verbose=True)
# Out:
# gen	nevals	avg    	std    	min      	max
# 0  	300   	936.179	1118.65	-0.694689	6187.34
# 1  	195   	402.073	927.16 	-0.694689	6420.83
# 2  	186   	227.361	792.09 	-0.959191	6420.83
# 3  	203   	170.293	710.607	-0.986026	4001.61
# 4  	189   	120.658	615.763	-0.986518	6420.83
# 5  	194   	142.047	574.987	-0.991838	3999.46
# 6  	173   	112.961	573.119	-1.02154 	4298.83
# 7  	207   	121.753	585.832	-1.02154 	4268.83
# 8  	198   	124.53 	591.761	-1.02154 	6420.83
# 9  	203   	139.279	682.509	-1.02154 	6420.83
# 10 	192   	132.989	574.036	-1.02154 	3998.58
# 11 	186   	106.708	529.115	-1.02154 	4053.83
# 12 	195   	146.477	583.456	-1.02154 	3998.58
# 13 	210   	185.207	759.64 	-1.02154 	6370.83
# 14 	190   	128.397	552.296	-1.02154 	3998.58
# 15 	190   	158.774	603.026	-1.02154 	4000.83
# 16 	204   	211.019	786.676	-1.02154 	6420.83
# 17 	204   	104.392	517.142	-1.02154 	4975.83
# 18 	186   	112.658	493.046	-1.02154 	3998.58
# 19 	196   	159.661	690.89 	-1.02154 	6370.83
# ...

# %%
b=tools.selBest(pop, k=5)
#print(b)

# %%
for elem in b:
    print(eval(elem))
# Out:
# (-1.0215408655544027,)
# (-1.0215408655544027,)
# (-1.0215408655544027,)
# (-1.0215408655544027,)
# (-1.0215408655544027,)
